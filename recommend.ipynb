# %%
import numpy as np 
import pandas as pd

# %%
books=pd.read_csv('Books.csv',dtype={3: str},low_memory=False)
users=pd.read_csv('Users.csv',dtype={3: str},low_memory=False)
ratings=pd.read_csv('Ratings.csv',dtype={3: str},low_memory=False)

# %%
books.head()
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# ...

# %%
users.head()
# Out:
#    User-ID                            Location   Age
# 0        1                  nyc, new york, usa   NaN
# 1        2           stockton, california, usa  18.0
# 2        3     moscow, yukon territory, russia   NaN
# 3        4           porto, v.n.gaia, portugal  17.0
# 4        5  farnborough, hants, united kingdom   NaN

# %%
ratings.head()
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6

# %%
print(books.shape)
print(ratings.shape)
print(users.shape)
# Out:
# (271360, 8)
# (1149780, 3)
# (278858, 3)

# %%
books.isnull().sum()
# Out:
# ISBN                   0
# Book-Title             0
# Book-Author            2
# Year-Of-Publication    0
# Publisher              2
# Image-URL-S            0
# Image-URL-M            0
# Image-URL-L            3
# dtype: int64

# %%
users.isnull().sum()
# Out:
# User-ID          0
# Location         0
# Age         110762
# dtype: int64

# %%
ratings.isnull().sum()
# Out:
# User-ID        0
# ISBN           0
# Book-Rating    0
# dtype: int64

# %%
books.duplicated().sum()
# Out:
# 0

# %%
ratings.duplicated().sum()
# Out:
# 0

# %%
users.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Popularity Based Recommender System

# %%
 ratings_with_name =ratings.merge(books,on='ISBN')

# %%
 num_rating_df=ratings_with_name.groupby('Book-Title').count()['Book-Rating'].reset_index()
 num_rating_df.rename(columns={'Book-Rating':'num_rating'},inplace=True)
 num_rating_df
# Out:
#                                                Book-Title  num_rating
# 0        A Light in the Storm: The Civil War Diary of ...           4
# 1                                   Always Have Popsicles           1
# 2                    Apple Magic (The Collector's series)           1
# 3        Ask Lily (Young Women of Faith: Lily Series, ...           1
# 4        Beyond IBM: Leadership Marketing and Finance ...           1
# ...                                                   ...         ...
# 241066                                      Ã?Â?lpiraten.           2
# 241067                     Ã?Â?rger mit Produkt X. Roman.           4
# 241068                                Ã?Â?sterlich leben.           1
# 241069                              Ã?Â?stlich der Berge.           3
# 241070                                  Ã?Â?thique en toc           2
#
# [241071 rows x 2 columns]

# %%
ratings_with_name['Book-Rating'] = pd.to_numeric(ratings_with_name['Book-Rating'], errors='coerce')

# %%
ratings_with_name.dropna(subset=['Book-Rating'], inplace=True)

# %%
avg_rating_df = ratings_with_name.groupby('Book-Title', as_index=False)['Book-Rating'].mean()
avg_rating_df.rename(columns={'Book-Rating': 'avg_ratings'}, inplace=True)
avg_rating_df
# Out:
#                                                Book-Title  avg_ratings
# 0        A Light in the Storm: The Civil War Diary of ...     2.250000
# 1                                   Always Have Popsicles     0.000000
# 2                    Apple Magic (The Collector's series)     0.000000
# 3        Ask Lily (Young Women of Faith: Lily Series, ...     8.000000
# 4        Beyond IBM: Leadership Marketing and Finance ...     0.000000
# ...                                                   ...          ...
# 241066                                      Ã?Â?lpiraten.     0.000000
# 241067                     Ã?Â?rger mit Produkt X. Roman.     5.250000
# 241068                                Ã?Â?sterlich leben.     7.000000
# 241069                              Ã?Â?stlich der Berge.     2.666667
# 241070                                  Ã?Â?thique en toc     4.000000
#
# [241071 rows x 2 columns]

# %%
popular_df=num_rating_df.merge(avg_rating_df,on='Book-Title')
popular_df
# Out:
#                                                Book-Title  num_rating  \
# 0        A Light in the Storm: The Civil War Diary of ...           4
# 1                                   Always Have Popsicles           1
# 2                    Apple Magic (The Collector's series)           1
# 3        Ask Lily (Young Women of Faith: Lily Series, ...           1
# 4        Beyond IBM: Leadership Marketing and Finance ...           1
# ...                                                   ...         ...
# 241066                                      Ã?Â?lpiraten.           2
# 241067                     Ã?Â?rger mit Produkt X. Roman.           4
# 241068                                Ã?Â?sterlich leben.           1
# 241069                              Ã?Â?stlich der Berge.           3
# 241070                                  Ã?Â?thique en toc           2
#
#         avg_ratings
# 0          2.250000
# 1          0.000000
# 2          0.000000
# 3          8.000000
# ...

# %%
  popular_df=popular_df[popular_df['num_rating']>=250].sort_values('avg_ratings',ascending=False).head(50)

# %%
print(popular_df.columns)
print(books.columns)
# Out:
# Index(['Book-Title', 'Book-Author', 'Image-URL-M', 'num_rating',
#        'avg_ratings'],
#       dtype='object')
# Index(['ISBN', 'Book-Title', 'Book-Author', 'Year-Of-Publication', 'Publisher',
#        'Image-URL-S', 'Image-URL-M', 'Image-URL-L'],
#       dtype='object')

# %%
 popular_df=popular_df.merge(books,on='Book-Title').drop_duplicates('Book-Title')[['Book-Title', 'Book-Author', 'Image-URL-M', 'num_rating',
       'avg_ratings']]

# %%
popular_df
# Out:
#                                             Book-Title  \
# 0    Harry Potter and the Prisoner of Azkaban (Book 3)
# 3         Harry Potter and the Goblet of Fire (Book 4)
# 5       Harry Potter and the Sorcerer's Stone (Book 1)
# 9    Harry Potter and the Order of the Phoenix (Boo...
# 13    Harry Potter and the Chamber of Secrets (Book 2)
# 16   The Hobbit : The Enchanting Prelude to The Lor...
# 17   The Fellowship of the Ring (The Lord of the Ri...
# 26   Harry Potter and the Sorcerer's Stone (Harry P...
# 28      The Two Towers (The Lord of the Rings, Part 2)
# 39                               To Kill a Mockingbird
# 47                                   The Da Vinci Code
# 53                  The Five People You Meet in Heaven
# 55                              The Catcher in the Rye
# 62                           The Lovely Bones: A Novel
# 63                                                1984
# 72                            Prodigal Summer: A Novel
# ...

# %% [markdown]
#  # Collaborative Filtering Based Recommender System

# %%
x=ratings_with_name.groupby('User-ID').count()['Book-Rating'] >200
padhne_users=x[x].index

# %%
 filtered_rating=ratings_with_name[ratings_with_name['User-ID'].isin(padhne_users)]

# %%
y=filtered_rating.groupby('Book-Title').count()['Book-Rating']>=50
famous_books=y[y].index

# %%
final_ratings=filtered_rating[filtered_rating['Book-Title'].isin(famous_books)]

# %%
pt=final_ratings.pivot_table(index='Book-Title',columns='User-ID',values='Book-Rating')

# %%
pt.fillna(0,inplace=True)

# %%
pt
# Out:
# User-ID                                             254     2276    2766    \
# Book-Title
# 1984                                                   9.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0    10.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     7.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# ...

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
 similarity_scores=cosine_similarity(pt)

# %%
similarity_scores
# Out:
# array([[1.        , 0.10255025, 0.01220856, ..., 0.12110367, 0.07347567,
#         0.04316046],
#        [0.10255025, 1.        , 0.2364573 , ..., 0.07446129, 0.16773875,
#         0.14263397],
#        [0.01220856, 0.2364573 , 1.        , ..., 0.04558758, 0.04938579,
#         0.10796119],
#        ...,
#        [0.12110367, 0.07446129, 0.04558758, ..., 1.        , 0.07085128,
#         0.0196177 ],
#        [0.07347567, 0.16773875, 0.04938579, ..., 0.07085128, 1.        ,
#         0.10602962],
#        [0.04316046, 0.14263397, 0.10796119, ..., 0.0196177 , 0.10602962,
#         1.        ]])

# %%
similarity_scores.shape
# Out:
# (706, 706)

# %%
def recommend(book_name):
    index=np.where(pt.index=='Zoya')[0][0]
    distances=similarity_scores[index]
    return suggestions

# %%
np.where(pt.index=='Zoya')[0][0]
# Out:
# 704

# %%
sorted(list(enumerate(similarity_scores[0])),key=lambda x:x[1],reverse=True)[1:6]
# Out:
# [(47, 0.2702651417103732),
#  (545, 0.2639619371123496),
#  (82, 0.2366937434740099),
#  (634, 0.23299389358170397),
#  (551, 0.2262639743141286)]

# %%
import numpy as np

def recommend(book_name):
    index = np.where(pt.index == book_name)[0][0]
    similar_items = sorted(list(enumerate(similarity_scores[index])), key=lambda x: x[1], reverse=True)[1:6]
    
    data = []
    
    for i in similar_items:
        item = []
        temp_df = books[books['Book-Title'] == pt.index[i[0]]]

        # Fix method name & indentation
        item.append(list(temp_df.drop_duplicates('Book-Title')['Book-Title'].values))
        item.append(list(temp_df.drop_duplicates('Book-Title')['Book-Author'].values))
        item.append(list(temp_df.drop_duplicates('Book-Title')['Image-URL-M'].values))

        data.append(item)
    
    return data

# %%
recommend('1984')
# Out:
# [[['Animal Farm'],
#   ['George Orwell'],
#   ['http://images.amazon.com/images/P/0451526341.01.MZZZZZZZ.jpg']],
#  [["The Handmaid's Tale"],
#   ['Margaret Atwood'],
#   ['http://images.amazon.com/images/P/0449212602.01.MZZZZZZZ.jpg']],
#  [['Brave New World'],
#   ['Aldous Huxley'],
#   ['http://images.amazon.com/images/P/0060809833.01.MZZZZZZZ.jpg']],
#  [['The Vampire Lestat (Vampire Chronicles, Book II)'],
#   ['ANNE RICE'],
#   ['http://images.amazon.com/images/P/0345313860.01.MZZZZZZZ.jpg']],
#  [['The Hours : A Novel'],
#   ['Michael Cunningham'],
#   ['http://images.amazon.com/images/P/0312243022.01.MZZZZZZZ.jpg']]]

# %%
import numpy as np
import pandas as pd
import heapq
from sklearn.metrics.pairwise import cosine_similarity

# Simulated Data (You'll need to use your actual 'pt' and 'books' DataFrames here)
# 'pt' is a DataFrame with book titles as index and features as columns
# 'books' is a DataFrame with 'Book-Title', 'Book-Author', 'Image-URL-M'

# Assuming pt and books are already loaded DataFrames

# Cache for storing similarity results
book_similarity_cache = {}

def recommend_books():
    user_input = input("Enter the book title for recommendations: ").strip()

    # Check if the book exists in the index
    if user_input not in pt.index:
        print("Book not found. Please try again with a different title.")
        return

    recommendations = []

    # Use cached similarity scores if available
    if user_input in book_similarity_cache:
        distances, indices = book_similarity_cache[user_input]
        sorted_indices = np.argsort(distances)[::-1]  # Sort indices in descending order of similarity

        for idx in sorted_indices[:20]:  # Get top 20 books
            book_title = pt.index[indices[idx]]
            book_info = books[books["Book-Title"] == str(book_title)]

            if not book_info.empty:
                author = book_info.iloc[0]["Book-Author"]
                image_url = book_info.iloc[0]["Image-URL-M"]

                recommendations.append({
                    "book_title": book_title,
                    "similarity": round(distances[idx], 2),
                    "author": author,
                    "image_url": image_url
                })

    else:
        # Calculate cosine similarity manually and update cache
        input_vector = pt.loc[user_input].values
        heap = []

        for book_title in pt.index:
            if book_title == user_input:
                continue  # Skip self
            book_vector = pt.loc[book_title].values
            similarity = cosine_similarity([input_vector], [book_vector])[0][0]

            heapq.heappush(heap, (-similarity, book_title))  # Store negative similarity to make max-heap

        # Extract top 20 books with highest similarity
        for _ in range(min(20, len(heap))):
            similarity, book_title = heapq.heappop(heap)  # Pop most similar books
            similarity = -similarity  # Convert back to positive similarity

            book_info = books[books["Book-Title"] == book_title]
            if not book_info.empty:
                author = book_info.iloc[0]["Book-Author"]
                image_url = book_info.iloc[0]["Image-URL-M"]

                recommendations.append({
                    "book_title": book_title,
                    "similarity": round(similarity, 2),
                    "author": author,
                    "image_url": image_url
                })

        # Update book_similarity_cache properly
        distances = [rec["similarity"] for rec in recommendations]
        indices = [pt.index.get_loc(rec["book_title"]) for rec in recommendations if rec["book_title"] in pt.index]

        book_similarity_cache[user_input] = (distances, indices)  # Store results in cache

    # Display the recommendations
    if recommendations:
        print("\nTop 20 Recommended Books:")
        for rec in recommendations:
            print(f"Title: {rec['book_title']}")
            print(f"Author: {rec['author']}")
            print(f"Similarity: {rec['similarity']}")
            print(f"Image URL: {rec['image_url']}")
            print("-" * 40)

# Call the function to test it
recommend_books()
# Out:
# Enter the book title for recommendations:  1984
# Top 20 Recommended Books:
# Title: Animal Farm
# Author: George Orwell
# Similarity: 0.27
# Image URL: http://images.amazon.com/images/P/0451526341.01.MZZZZZZZ.jpg
# ----------------------------------------
# Title: The Handmaid's Tale
# Author: Margaret Atwood
# Similarity: 0.26
# Image URL: http://images.amazon.com/images/P/0449212602.01.MZZZZZZZ.jpg
# ----------------------------------------
# Title: Brave New World
# Author: Aldous Huxley
# Similarity: 0.24
# Image URL: http://images.amazon.com/images/P/0060809833.01.MZZZZZZZ.jpg
# ----------------------------------------
# Title: The Vampire Lestat (Vampire Chronicles, Book II)
# Author: ANNE RICE
# Similarity: 0.23
# Image URL: http://images.amazon.com/images/P/0345313860.01.MZZZZZZZ.jpg
# ----------------------------------------
# Title: The Hours : A Novel
# Author: Michael Cunningham
# Similarity: 0.23
# Image URL: http://images.amazon.com/images/P/0312243022.01.MZZZZZZZ.jpg
# ...

# %%
import numpy as np
import pandas as pd
import heapq
from sklearn.metrics.pairwise import cosine_similarity

# Simulated Data (You'll need to use your actual 'pt' and 'books' DataFrames here)
# 'pt' is a DataFrame with book titles as index and features as columns
# 'books' is a DataFrame with 'Book-Title', 'Book-Author', 'Image-URL-M'

# Assuming pt and books are already loaded DataFrames

# Cache for storing similarity results
book_similarity_cache = {}

def recommend_books():
    user_input = input("Enter the book title for recommendations: ").strip()

    # Check if the book exists in the index
    if user_input not in pt.index:
        print("Book not found. Please try again with a different title.")
        return

    recommendations = []

    # Use cached similarity scores if available
    if user_input in book_similarity_cache:
        distances, indices = book_similarity_cache[user_input]
        sorted_indices = np.argsort(distances)[::-1]  # Sort indices in descending order of similarity

        for idx in sorted_indices[:20]:  # Get top 20 books
            book_title = pt.index[indices[idx]]
            book_info = books[books["Book-Title"] == str(book_title)]

            if not book_info.empty:
                author = book_info.iloc[0]["Book-Author"]
                image_url = book_info.iloc[0]["Image-URL-M"]

                recommendations.append({
                    "book_title": book_title,
                    "similarity": round(distances[idx], 2),
                    "author": author,
                    "image_url": image_url
                })

    else:
        # Calculate cosine similarity manually and update cache
        input_vector = pt.loc[user_input].values
        heap = []

        for book_title in pt.index:
            if book_title == user_input:
                continue  # Skip self
            book_vector = pt.loc[book_title].values
            similarity = cosine_similarity([input_vector], [book_vector])[0][0]

            heapq.heappush(heap, (-similarity, book_title))  # Store negative similarity to make max-heap

        # Extract top 20 books with highest similarity
        for _ in range(min(20, len(heap))):
            similarity, book_title = heapq.heappop(heap)  # Pop most similar books
            similarity = -similarity  # Convert back to positive similarity

            book_info = books[books["Book-Title"] == book_title]
            if not book_info.empty:
                author = book_info.iloc[0]["Book-Author"]
                image_url = book_info.iloc[0]["Image-URL-M"]

                recommendations.append({
                    "book_title": book_title,
                    "similarity": round(similarity, 2),
                    "author": author,
                    "image_url": image_url
                })

        # Update book_similarity_cache properly
        distances = [rec["similarity"] for rec in recommendations]
        indices = [pt.index.get_loc(rec["book_title"]) for rec in recommendations if rec["book_title"] in pt.index]

        book_similarity_cache[user_input] = (distances, indices)  # Store results in cache

    # Display the recommendations
    if recommendations:
        print("\nTop 20 Recommended Books:")
        for rec in recommendations:
            print(f"Title: {rec['book_title']}")
            print(f"Author: {rec['author']}")
            print(f"Similarity: {rec['similarity']}")
            print(f"Image URL: {rec['image_url']}")
            print("-" * 40)

# Call the function to test it
recommend_books()
# Out:
# Enter the book title for recommendations:  Pride and Prejudice
# Top 20 Recommended Books:
# Title: The English Patient
# Author: Michael Ondaatje
# Similarity: 0.26
# Image URL: http://images.amazon.com/images/P/0679745203.01.MZZZZZZZ.jpg
# ----------------------------------------
# Title: How to Be Good
# Author: Nick Hornby
# Similarity: 0.24
# Image URL: http://images.amazon.com/images/P/1573229326.01.MZZZZZZZ.jpg
# ----------------------------------------
# Title: Two for the Dough
# Author: Janet Evanovich
# Similarity: 0.2
# Image URL: http://images.amazon.com/images/P/0671001795.01.MZZZZZZZ.jpg
# ----------------------------------------
# Title: Rising Sun
# Author: MICHAEL CRICHTON
# Similarity: 0.2
# Image URL: http://images.amazon.com/images/P/0345380371.01.MZZZZZZZ.jpg
# ----------------------------------------
# Title: 4 Blondes
# Author: Candace Bushnell
# Similarity: 0.19
# Image URL: http://images.amazon.com/images/P/0451203895.01.MZZZZZZZ.jpg
# ...

# %%
import pickle 
pickle.dump(popular_df,open('popular.pkl','wb'))

# %%
pickle.dump(pt,open('pt.pkl','wb'))
pickle.dump(books,open('books.pkl','wb'))
pickle.dump(book_similarity_cache,open('book_similarity_cache.pkl','wb'))
